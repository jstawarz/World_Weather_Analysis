# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | evensk
# Processing Record 2 of Set 1 | balotra
# Processing Record 3 of Set 1 | los llanos de aridane
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | geraldton
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | mareeba
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | belyy yar
# Processing Record 10 of Set 1 | margate
# Processing Record 11 of Set 1 | suhbaatar
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | takhtamygda
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | cherskiy
# Processing Record 17 of Set 1 | egvekinot
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | noumea
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | tabory
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | garowe
# Processing Record 26 of Set 1 | husavik
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | chuy
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | tanete
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | uarini
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | asyut
# Processing Record 40 of Set 1 | sosnovo-ozerskoye
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | coquimbo
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | trinidad
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | ukiah
# Processing Record 49 of Set 1 | comodoro rivadavia
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | tessalit
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | santa cruz
# Processing Record 4 of Set 2 | ixtapa
# Processing Record 5 of Set 2 | tabou
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | te anau
# Processing Record 8 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | sechura
# Processing Record 12 of Set 2 | kununurra
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | buraydah
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | henties bay
# Processing Record 19 of Set 2 | manzil tamim
# City not found. Skipping...
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | baruun-urt
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | am timan
# Processing Record 26 of Set 2 | tres arroyos
# Processing Record 27 of Set 2 | benghazi
# Processing Record 28 of Set 2 | sorong
# Processing Record 29 of Set 2 | yulara
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | saint-pierre
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | abu samrah
# Processing Record 35 of Set 2 | bandarbeyla
# Processing Record 36 of Set 2 | tank
# Processing Record 37 of Set 2 | ambovombe
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | unye
# City not found. Skipping...
# Processing Record 41 of Set 2 | mwinilunga
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | banda aceh
# Processing Record 44 of Set 2 | kota
# Processing Record 45 of Set 2 | pacific grove
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | ginda
# Processing Record 48 of Set 2 | deming
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | ararat
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | atar
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | baykit
# Processing Record 6 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | asau
# Processing Record 9 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | ambilobe
# Processing Record 12 of Set 3 | san andres
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | haines junction
# Processing Record 15 of Set 3 | kralendijk
# Processing Record 16 of Set 3 | razgrad
# Processing Record 17 of Set 3 | upernavik
# Processing Record 18 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 3 | nyurba
# Processing Record 20 of Set 3 | kyra
# Processing Record 21 of Set 3 | malinovskiy
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | along
# Processing Record 25 of Set 3 | lasa
# Processing Record 26 of Set 3 | dicabisagan
# Processing Record 27 of Set 3 | caravelas
# Processing Record 28 of Set 3 | sibu
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | namwala
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | marapanim
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | plettenberg bay
# Processing Record 38 of Set 3 | mitsamiouli
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | rio gallegos
# Processing Record 42 of Set 3 | zyryanka
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | varhaug
# Processing Record 45 of Set 3 | zimovniki
# Processing Record 46 of Set 3 | goundam
# Processing Record 47 of Set 3 | freeport
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | langsa
# Processing Record 50 of Set 3 | dunedin
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | ust-kan
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | simpang
# Processing Record 5 of Set 4 | miri
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | kinsale
# Processing Record 8 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 4 | the pas
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | maumere
# Processing Record 12 of Set 4 | chicama
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | jawar
# Processing Record 17 of Set 4 | belaya gora
# Processing Record 18 of Set 4 | oranjemund
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | mao
# Processing Record 22 of Set 4 | emerald
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | kinablangan
# Processing Record 25 of Set 4 | omboue
# Processing Record 26 of Set 4 | shelburne
# Processing Record 27 of Set 4 | solnechnyy
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | pavlodolskaya
# Processing Record 30 of Set 4 | namibe
# Processing Record 31 of Set 4 | humaita
# Processing Record 32 of Set 4 | hami
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | shenjiamen
# Processing Record 38 of Set 4 | sorland
# Processing Record 39 of Set 4 | najran
# Processing Record 40 of Set 4 | moose factory
# Processing Record 41 of Set 4 | fairbanks
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | boatlaname
# City not found. Skipping...
# Processing Record 44 of Set 4 | pasan
# Processing Record 45 of Set 4 | kawalu
# Processing Record 46 of Set 4 | skibbereen
# Processing Record 47 of Set 4 | kondinskoye
# Processing Record 48 of Set 4 | puro
# Processing Record 49 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 4 | saint-augustin
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | itarema
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | dudinka
# Processing Record 6 of Set 5 | jalu
# Processing Record 7 of Set 5 | buala
# Processing Record 8 of Set 5 | komsomolskiy
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | tagusao
# Processing Record 12 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | mehamn
# Processing Record 15 of Set 5 | vila franca do campo
# Processing Record 16 of Set 5 | helong
# Processing Record 17 of Set 5 | san javier
# Processing Record 18 of Set 5 | moosomin
# Processing Record 19 of Set 5 | half moon bay
# Processing Record 20 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 5 | muros
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | lagoa
# Processing Record 24 of Set 5 | gobabis
# Processing Record 25 of Set 5 | port keats
# Processing Record 26 of Set 5 | victoria
# Processing Record 27 of Set 5 | tres pontas
# Processing Record 28 of Set 5 | biltine
# Processing Record 29 of Set 5 | balikpapan
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 5 | eidfjord
# Processing Record 33 of Set 5 | portland
# Processing Record 34 of Set 5 | fethiye
# Processing Record 35 of Set 5 | petrolina
# Processing Record 36 of Set 5 | nishihara
# Processing Record 37 of Set 5 | monte aprazivel
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | jinka
# Processing Record 40 of Set 5 | mogadishu
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | east london
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | vestmannaeyjar
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | beira
# Processing Record 47 of Set 5 | nanzhang
# Processing Record 48 of Set 5 | pisco
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | maryville
# Processing Record 2 of Set 6 | dikson
# Processing Record 3 of Set 6 | kilindoni
# Processing Record 4 of Set 6 | hambantota
# Processing Record 5 of Set 6 | smirnykh
# Processing Record 6 of Set 6 | reconquista
# Processing Record 7 of Set 6 | fort nelson
# Processing Record 8 of Set 6 | kapoeta
# Processing Record 9 of Set 6 | evanston
# Processing Record 10 of Set 6 | kjollefjord
# Processing Record 11 of Set 6 | havre-saint-pierre
# Processing Record 12 of Set 6 | butaritari
# Processing Record 13 of Set 6 | kamenka
# Processing Record 14 of Set 6 | creel
# Processing Record 15 of Set 6 | simplicio mendes
# Processing Record 16 of Set 6 | isla mujeres
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | ust-koksa
# Processing Record 19 of Set 6 | marzuq
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | shubarkuduk
# Processing Record 22 of Set 6 | leon
# Processing Record 23 of Set 6 | eureka
# Processing Record 24 of Set 6 | tommot
# Processing Record 25 of Set 6 | dalby
# Processing Record 26 of Set 6 | ketchikan
# Processing Record 27 of Set 6 | saskylakh
# Processing Record 28 of Set 6 | nelson bay
# Processing Record 29 of Set 6 | samarai
# Processing Record 30 of Set 6 | mezen
# Processing Record 31 of Set 6 | roebourne
# Processing Record 32 of Set 6 | tuy hoa
# Processing Record 33 of Set 6 | sakaiminato
# Processing Record 34 of Set 6 | dubbo
# Processing Record 35 of Set 6 | knysna
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | chissamba
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | wagga wagga
# Processing Record 40 of Set 6 | bambanglipuro
# Processing Record 41 of Set 6 | marsabit
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | westport
# Processing Record 44 of Set 6 | byron bay
# Processing Record 45 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | myitkyina
# Processing Record 48 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 49 of Set 6 | puerto escondido
# Processing Record 50 of Set 6 | teguise
# Processing Record 1 of Set 7 | nipawin
# Processing Record 2 of Set 7 | soria
# Processing Record 3 of Set 7 | afrikanda
# Processing Record 4 of Set 7 | cervo
# Processing Record 5 of Set 7 | rochegda
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | sunrise manor
# Processing Record 8 of Set 7 | sitrah
# Processing Record 9 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 7 | linxia
# Processing Record 11 of Set 7 | grand forks
# Processing Record 12 of Set 7 | ibra
# Processing Record 13 of Set 7 | napoleon
# Processing Record 14 of Set 7 | regina
# Processing Record 15 of Set 7 | nuuk
# Processing Record 16 of Set 7 | bengkulu
# Processing Record 17 of Set 7 | labe
# Processing Record 18 of Set 7 | waw
# Processing Record 19 of Set 7 | neuquen
# Processing Record 20 of Set 7 | bayan
# Processing Record 21 of Set 7 | sabha
# Processing Record 22 of Set 7 | ariquemes
# Processing Record 23 of Set 7 | general roca
# Processing Record 24 of Set 7 | yerbogachen
# Processing Record 25 of Set 7 | rebrikha
# Processing Record 26 of Set 7 | biryusinsk
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | guangyuan
# Processing Record 29 of Set 7 | sonoita
# Processing Record 30 of Set 7 | marshfield
# Processing Record 31 of Set 7 | swan river
# Processing Record 32 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 7 | flin flon
# Processing Record 34 of Set 7 | hashtrud
# Processing Record 35 of Set 7 | aksarka
# Processing Record 36 of Set 7 | moranbah
# Processing Record 37 of Set 7 | zhigansk
# Processing Record 38 of Set 7 | nadym
# Processing Record 39 of Set 7 | salalah
# Processing Record 40 of Set 7 | saint-joseph
# Processing Record 41 of Set 7 | natal
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | ordzhonikidze
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | taoudenni
# Processing Record 46 of Set 7 | lunca
# Processing Record 47 of Set 7 | kyren
# Processing Record 48 of Set 7 | tiznit
# Processing Record 49 of Set 7 | turbat
# Processing Record 50 of Set 7 | isangel
# Processing Record 1 of Set 8 | innisfail
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | guna
# Processing Record 4 of Set 8 | haicheng
# Processing Record 5 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 8 | port augusta
# Processing Record 7 of Set 8 | koumac
# Processing Record 8 of Set 8 | brasilia
# Processing Record 9 of Set 8 | churapcha
# Processing Record 10 of Set 8 | tamuin
# Processing Record 11 of Set 8 | rongcheng
# Processing Record 12 of Set 8 | tovarkovskiy
# Processing Record 13 of Set 8 | stornoway
# Processing Record 14 of Set 8 | lompoc
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | svetlaya
# Processing Record 17 of Set 8 | kamina
# Processing Record 18 of Set 8 | beloha
# Processing Record 19 of Set 8 | faya
# Processing Record 20 of Set 8 | west wendover
# Processing Record 21 of Set 8 | lake ridge
# Processing Record 22 of Set 8 | inyonga
# Processing Record 23 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | iralaya
# Processing Record 26 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 8 | saint john
# Processing Record 28 of Set 8 | karratha
# Processing Record 29 of Set 8 | lensk
# Processing Record 30 of Set 8 | deputatskiy
# Processing Record 31 of Set 8 | lavrentiya
# Processing Record 32 of Set 8 | atka
# City not found. Skipping...
# Processing Record 33 of Set 8 | dingle
# Processing Record 34 of Set 8 | oum hadjer
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | stara moravica
# Processing Record 37 of Set 8 | athabasca
# Processing Record 38 of Set 8 | predivinsk
# Processing Record 39 of Set 8 | puerto narino
# Processing Record 40 of Set 8 | labuhan
# Processing Record 41 of Set 8 | neiafu
# Processing Record 42 of Set 8 | kande
# Processing Record 43 of Set 8 | wloszczowa
# Processing Record 44 of Set 8 | port pirie
# Processing Record 45 of Set 8 | tilichiki
# Processing Record 46 of Set 8 | talara
# Processing Record 47 of Set 8 | zakamensk
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | ayan
# Processing Record 1 of Set 9 | kapit
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | dharchula
# Processing Record 4 of Set 9 | quatre cocos
# Processing Record 5 of Set 9 | ndende
# Processing Record 6 of Set 9 | peniche
# Processing Record 7 of Set 9 | mount isa
# Processing Record 8 of Set 9 | clyde river
# Processing Record 9 of Set 9 | salo
# Processing Record 10 of Set 9 | morada nova
# Processing Record 11 of Set 9 | yuanping
# Processing Record 12 of Set 9 | middle island
# Processing Record 13 of Set 9 | brawley
# Processing Record 14 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 15 of Set 9 | luanda
# Processing Record 16 of Set 9 | baza
# Processing Record 17 of Set 9 | beringovskiy
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | cachoeira do sul
# Processing Record 20 of Set 9 | north vernon
# Processing Record 21 of Set 9 | kon tum
# Processing Record 22 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 9 | lazaro cardenas
# Processing Record 25 of Set 9 | shawville
# Processing Record 26 of Set 9 | praia da vitoria
# Processing Record 27 of Set 9 | pedernales
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | bilibino
# Processing Record 30 of Set 9 | camacupa
# Processing Record 31 of Set 9 | cabedelo
# Processing Record 32 of Set 9 | kailua
# Processing Record 33 of Set 9 | aykhal
# Processing Record 34 of Set 9 | vrangel
# Processing Record 35 of Set 9 | poum
# Processing Record 36 of Set 9 | luancheng
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | carcassonne
# Processing Record 39 of Set 9 | carutapera
# Processing Record 40 of Set 9 | diebougou
# Processing Record 41 of Set 9 | port-gentil
# Processing Record 42 of Set 9 | guerrero negro
# Processing Record 43 of Set 9 | cayenne
# Processing Record 44 of Set 9 | turka
# Processing Record 45 of Set 9 | vostok
# Processing Record 46 of Set 9 | koutsouras
# Processing Record 47 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | oranjestad
# Processing Record 49 of Set 9 | pucallpa
# Processing Record 50 of Set 9 | lorengau
# Processing Record 1 of Set 10 | zemio
# Processing Record 2 of Set 10 | faridan
# City not found. Skipping...
# Processing Record 3 of Set 10 | murdochville
# Processing Record 4 of Set 10 | huarmey
# Processing Record 5 of Set 10 | amga
# Processing Record 6 of Set 10 | weihe
# Processing Record 7 of Set 10 | mindelo
# Processing Record 8 of Set 10 | san luis
# Processing Record 9 of Set 10 | kachiry
# Processing Record 10 of Set 10 | klerksdorp
# Processing Record 11 of Set 10 | ngunguru
# Processing Record 12 of Set 10 | havoysund
# Processing Record 13 of Set 10 | beyneu
# Processing Record 14 of Set 10 | altamont
# Processing Record 15 of Set 10 | tonantins
# Processing Record 16 of Set 10 | khurai
# Processing Record 17 of Set 10 | mackenzie
# Processing Record 18 of Set 10 | manacapuru
# Processing Record 19 of Set 10 | payo
# Processing Record 20 of Set 10 | dickinson
# Processing Record 21 of Set 10 | maniitsoq
# Processing Record 22 of Set 10 | ojinaga
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | sarakhs
# Processing Record 25 of Set 10 | campos gerais
# Processing Record 26 of Set 10 | sao miguel do araguaia
# Processing Record 27 of Set 10 | orlovskiy
# Processing Record 28 of Set 10 | gat
# Processing Record 29 of Set 10 | garachine
# Processing Record 30 of Set 10 | huinan
# Processing Record 31 of Set 10 | nemuro
# Processing Record 32 of Set 10 | krasnyy yar
# Processing Record 33 of Set 10 | foumban
# Processing Record 34 of Set 10 | prince rupert
# Processing Record 35 of Set 10 | dodoma
# Processing Record 36 of Set 10 | teseney
# Processing Record 37 of Set 10 | port-cartier
# Processing Record 38 of Set 10 | chimbote
# Processing Record 39 of Set 10 | dhidhdhoo
# Processing Record 40 of Set 10 | porangatu
# Processing Record 41 of Set 10 | yaan
# Processing Record 42 of Set 10 | soyo
# Processing Record 43 of Set 10 | micheweni
# Processing Record 44 of Set 10 | mountmellick
# Processing Record 45 of Set 10 | livingstonia
# Processing Record 46 of Set 10 | sao joao da barra
# Processing Record 47 of Set 10 | davila
# Processing Record 48 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 10 | moron
# Processing Record 50 of Set 10 | ratangarh
# Processing Record 1 of Set 11 | noshiro
# Processing Record 2 of Set 11 | longyearbyen
# Processing Record 3 of Set 11 | frederico westphalen
# Processing Record 4 of Set 11 | ust-omchug
# Processing Record 5 of Set 11 | san quintin
# Processing Record 6 of Set 11 | paraiso
# Processing Record 7 of Set 11 | chimbarongo
# Processing Record 8 of Set 11 | gushikawa
# Processing Record 9 of Set 11 | iwanai
# Processing Record 10 of Set 11 | yumen
# Processing Record 11 of Set 11 | erbaa
# Processing Record 12 of Set 11 | manokwari
# Processing Record 13 of Set 11 | paratebueno
# Processing Record 14 of Set 11 | ashland
# Processing Record 15 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 11 | la ronge
# Processing Record 17 of Set 11 | sakakah
# Processing Record 18 of Set 11 | sunyani
# Processing Record 19 of Set 11 | kisangani
# Processing Record 20 of Set 11 | tutoia
# Processing Record 21 of Set 11 | natalio
# Processing Record 22 of Set 11 | veracruz
# Processing Record 23 of Set 11 | kungurtug
# Processing Record 24 of Set 11 | boca do acre
# Processing Record 25 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 26 of Set 11 | ushtobe
# Processing Record 27 of Set 11 | sola
# Processing Record 28 of Set 11 | bac lieu
# Processing Record 29 of Set 11 | pandan
# Processing Record 30 of Set 11 | vytegra
# Processing Record 31 of Set 11 | aquin
# Processing Record 32 of Set 11 | shumikha
# Processing Record 33 of Set 11 | rio grande
# Processing Record 34 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 35 of Set 11 | luderitz
# Processing Record 36 of Set 11 | manono
# Processing Record 37 of Set 11 | kismayo
# Processing Record 38 of Set 11 | pisz
# Processing Record 39 of Set 11 | hervey bay
# Processing Record 40 of Set 11 | oktyabrskiy
# Processing Record 41 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 42 of Set 11 | coihaique
# Processing Record 43 of Set 11 | tucuman
# Processing Record 44 of Set 11 | tuckahoe
# Processing Record 45 of Set 11 | aklavik
# Processing Record 46 of Set 11 | rock sound
# Processing Record 47 of Set 11 | birjand
# Processing Record 48 of Set 11 | cururupu
# Processing Record 49 of Set 11 | manoel urbano
# Processing Record 50 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 1 of Set 12 | harlow
# Processing Record 2 of Set 12 | ayagoz
# Processing Record 3 of Set 12 | hearst
# Processing Record 4 of Set 12 | bomet
# Processing Record 5 of Set 12 | butterworth
# Processing Record 6 of Set 12 | gander
# Processing Record 7 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 8 of Set 12 | manjakandriana
# Processing Record 9 of Set 12 | tecoanapa
# Processing Record 10 of Set 12 | brownwood
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | padang
# Processing Record 13 of Set 12 | bojonegoro
# Processing Record 14 of Set 12 | paulo ramos
# Processing Record 15 of Set 12 | vila
# Processing Record 16 of Set 12 | atambua
# Processing Record 17 of Set 12 | panjwin
# City not found. Skipping...
# Processing Record 18 of Set 12 | pyu
# Processing Record 19 of Set 12 | barranca
# Processing Record 20 of Set 12 | balclutha
# Processing Record 21 of Set 12 | sao jose da coroa grande
# Processing Record 22 of Set 12 | carauari
# Processing Record 23 of Set 12 | dori
# Processing Record 24 of Set 12 | aksu
# Processing Record 25 of Set 12 | kostomuksha
# Processing Record 26 of Set 12 | xuddur
# Processing Record 27 of Set 12 | ferrol
# Processing Record 28 of Set 12 | aleksinac
# Processing Record 29 of Set 12 | luwuk
# Processing Record 30 of Set 12 | teahupoo
# Processing Record 31 of Set 12 | cap malheureux
# Processing Record 32 of Set 12 | concordia
# Processing Record 33 of Set 12 | kieta
# Processing Record 34 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 35 of Set 12 | golakganj
# Processing Record 36 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 12 | yusva
# City not found. Skipping...
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | sistranda
# Processing Record 40 of Set 12 | ust-nera
# Processing Record 41 of Set 12 | wanaka
# Processing Record 42 of Set 12 | flinders
# Processing Record 43 of Set 12 | tibati
# Processing Record 44 of Set 12 | xai-xai
# Processing Record 45 of Set 12 | rincon
# Processing Record 46 of Set 12 | synya
# Processing Record 47 of Set 12 | jagtial
# Processing Record 48 of Set 12 | miandrivazo
# Processing Record 49 of Set 12 | le port
# Processing Record 50 of Set 12 | platteville
# Processing Record 1 of Set 13 | griffith
# Processing Record 2 of Set 13 | cibeureum
# Processing Record 3 of Set 13 | taunggyi
# Processing Record 4 of Set 13 | sinnamary
# Processing Record 5 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 13 | fernley
# Processing Record 7 of Set 13 | necochea
# Processing Record 8 of Set 13 | salinopolis
# Processing Record 9 of Set 13 | urumqi
# Processing Record 10 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 13 | launceston
# Processing Record 13 of Set 13 | obama
# Processing Record 14 of Set 13 | bria
# Processing Record 15 of Set 13 | burica
# City not found. Skipping...
# Processing Record 16 of Set 13 | vung tau
# Processing Record 17 of Set 13 | puerto leguizamo
# Processing Record 18 of Set 13 | almansa
# Processing Record 19 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 20 of Set 13 | hokitika
# Processing Record 21 of Set 13 | visby
# Processing Record 22 of Set 13 | lanzhou
# Processing Record 23 of Set 13 | sozopolis
# City not found. Skipping...
# Processing Record 24 of Set 13 | trairi
# Processing Record 25 of Set 13 | sadao
# Processing Record 26 of Set 13 | kassala
# Processing Record 27 of Set 13 | awbari
# Processing Record 28 of Set 13 | maarianhamina
# Processing Record 29 of Set 13 | lodi
# Processing Record 30 of Set 13 | pachino
# Processing Record 31 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 13 | teguldet
# Processing Record 33 of Set 13 | rangapara
# Processing Record 34 of Set 13 | at-bashi
# Processing Record 35 of Set 13 | khilok
# Processing Record 36 of Set 13 | port moresby
# Processing Record 37 of Set 13 | sabara
# Processing Record 38 of Set 13 | chengde
# Processing Record 39 of Set 13 | panzhihua
# Processing Record 40 of Set 13 | santa cruz de tenerife
# Processing Record 41 of Set 13 | porto novo
# Processing Record 42 of Set 13 | alexandria
# Processing Record 43 of Set 13 | katherine
# Processing Record 44 of Set 13 | medvedka
# Processing Record 45 of Set 13 | okhotsk
# Processing Record 46 of Set 13 | alyangula
# Processing Record 47 of Set 13 | toktogul
# Processing Record 48 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 13 | moussoro
# Processing Record 50 of Set 13 | ulladulla
# Processing Record 1 of Set 14 | suntar
# Processing Record 2 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 3 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 14 | tokonou
# Processing Record 5 of Set 14 | gharghoda
# Processing Record 6 of Set 14 | azangaro
# Processing Record 7 of Set 14 | acapulco
# Processing Record 8 of Set 14 | constantine
# Processing Record 9 of Set 14 | guanay
# Processing Record 10 of Set 14 | keti bandar
# Processing Record 11 of Set 14 | jaguaribe
# Processing Record 12 of Set 14 | warwick
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | santa fe
# City not found. Skipping...
# Processing Record 15 of Set 14 | kuvshinovo
# City not found. Skipping...
# Processing Record 16 of Set 14 | ville-marie
# City not found. Skipping...
# Processing Record 17 of Set 14 | pinega
# City not found. Skipping...
# Processing Record 18 of Set 14 | savona
# City not found. Skipping...
# Processing Record 19 of Set 14 | sokoni
# City not found. Skipping...
# Processing Record 20 of Set 14 | port hedland
# City not found. Skipping...
# Processing Record 21 of Set 14 | inhambane
# City not found. Skipping...
# Processing Record 22 of Set 14 | hauge
# City not found. Skipping...
# Processing Record 23 of Set 14 | srandakan
# City not found. Skipping...
# Processing Record 24 of Set 14 | nivala
# City not found. Skipping...
# Processing Record 25 of Set 14 | camopi
# City not found. Skipping...
# Processing Record 26 of Set 14 | mamburao
# City not found. Skipping...
# Processing Record 27 of Set 14 | puteyets
# City not found. Skipping...
# Processing Record 28 of Set 14 | eenhana
# City not found. Skipping...
# Processing Record 29 of Set 14 | ingham
# City not found. Skipping...
# Processing Record 30 of Set 14 | la rioja
# City not found. Skipping...
# Processing Record 31 of Set 14 | creston
# City not found. Skipping...
# Processing Record 32 of Set 14 | dwarka
# City not found. Skipping...
# Processing Record 33 of Set 14 | podporozhye
# City not found. Skipping...
# Processing Record 34 of Set 14 | bonnyville
# City not found. Skipping...
# Processing Record 35 of Set 14 | zhezkazgan
# City not found. Skipping...
# Processing Record 36 of Set 14 | kysyl-syr
# City not found. Skipping...
# Processing Record 37 of Set 14 | xacmaz
# City not found. Skipping...
# Processing Record 38 of Set 14 | villarrica
# City not found. Skipping...
# Processing Record 39 of Set 14 | okha
# City not found. Skipping...
# Processing Record 40 of Set 14 | takhatgarh
# City not found. Skipping...
# Processing Record 41 of Set 14 | tautira
# City not found. Skipping...
# Processing Record 42 of Set 14 | rena
# City not found. Skipping...
# Processing Record 43 of Set 14 | jieshi
# City not found. Skipping...
# Processing Record 44 of Set 14 | tabas
# City not found. Skipping...
# Processing Record 45 of Set 14 | caloundra
# City not found. Skipping...
# Processing Record 46 of Set 14 | concepcion del uruguay
# City not found. Skipping...
# Processing Record 47 of Set 14 | martapura
# City not found. Skipping...
# Processing Record 48 of Set 14 | bonavista
# City not found. Skipping...
# Processing Record 49 of Set 14 | jati
# City not found. Skipping...
# Processing Record 50 of Set 14 | mega
# City not found. Skipping...
# Processing Record 1 of Set 15 | kolokani
# City not found. Skipping...
# Processing Record 2 of Set 15 | balkhash
# City not found. Skipping...
# Processing Record 3 of Set 15 | lyuban
# City not found. Skipping...
# Processing Record 4 of Set 15 | lahaina
# City not found. Skipping...
# Processing Record 5 of Set 15 | aloleng
# City not found. Skipping...
# Processing Record 6 of Set 15 | goure
# City not found. Skipping...
# Processing Record 7 of Set 15 | manicore
# City not found. Skipping...
# Processing Record 8 of Set 15 | urengoy
# City not found. Skipping...
# Processing Record 9 of Set 15 | wanning
# City not found. Skipping...
# Processing Record 10 of Set 15 | nakhon phanom
# City not found. Skipping...
# Processing Record 11 of Set 15 | steamboat springs
# City not found. Skipping...
# Processing Record 12 of Set 15 | chabahar
# City not found. Skipping...
# Processing Record 13 of Set 15 | wewak
# City not found. Skipping...
# Processing Record 14 of Set 15 | winnemucca
# City not found. Skipping...
# Processing Record 15 of Set 15 | baltiysk
# City not found. Skipping...
# Processing Record 16 of Set 15 | khorramabad
# City not found. Skipping...
# Processing Record 17 of Set 15 | kutum
# City not found. Skipping...
# Processing Record 18 of Set 15 | mehran
# City not found. Skipping...
# Processing Record 19 of Set 15 | honiara
# City not found. Skipping...
# Processing Record 20 of Set 15 | sabang
# City not found. Skipping...
# Processing Record 21 of Set 15 | tadine
# City not found. Skipping...
# Processing Record 22 of Set 15 | shwebo
# City not found. Skipping...
# Processing Record 23 of Set 15 | kandrian
# City not found. Skipping...
# Processing Record 24 of Set 15 | bodden town
# City not found. Skipping...
# Processing Record 25 of Set 15 | painesville
# City not found. Skipping...
# Processing Record 26 of Set 15 | rudbar
# City not found. Skipping...
# Processing Record 27 of Set 15 | sao desiderio
# City not found. Skipping...
# Processing Record 28 of Set 15 | balao
# City not found. Skipping...
# Processing Record 29 of Set 15 | aswan
# City not found. Skipping...
# Processing Record 30 of Set 15 | tombouctou
# City not found. Skipping...
# Processing Record 31 of Set 15 | san jose iturbide
# City not found. Skipping...
# Processing Record 32 of Set 15 | zelenoborskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | riyadh
# City not found. Skipping...
# Processing Record 34 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 15 | seoul
# City not found. Skipping...
# Processing Record 36 of Set 15 | goderich
# City not found. Skipping...
# Processing Record 37 of Set 15 | stolbishche
# City not found. Skipping...
# Processing Record 38 of Set 15 | coolum beach
# City not found. Skipping...
# Processing Record 39 of Set 15 | bor
# City not found. Skipping...
# Processing Record 40 of Set 15 | chara
# City not found. Skipping...
# Processing Record 41 of Set 15 | naples
# City not found. Skipping...
# Processing Record 42 of Set 15 | olafsvik
# City not found. Skipping...
# Processing Record 43 of Set 15 | spetsai
# City not found. Skipping...
# Processing Record 44 of Set 15 | jacqueville
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Evensk      RU  61.9500  159.2333     31.86        41
# 1                Balotra      IN  25.8333   72.2333     85.05        68
# 2  Los Llanos De Aridane      ES  28.6585  -17.9182     72.12        76
# 3                  Bluff      NZ -46.6000  168.3333     54.81        76
# 4              Geraldton      AU -28.7667  114.6000     57.61        94
# 5                 Albany      US  42.6001  -73.9662     64.92        77
# 6                Mareeba      AU -17.0000  145.4333     73.44        86
# 7               Hermanus      ZA -34.4187   19.2345     58.89        84
# 8              Belyy Yar      RU  53.6039   91.3903     22.89        93
# 9                Margate      GB  51.3813    1.3862     57.69        91
#
#    Cloudiness  Wind Speed Current Description
# 0         100        9.40     overcast clouds
# 1          10       12.06           clear sky
# 2          20       13.80          few clouds
# 3          64       18.43          light rain
# 4          90        8.05     overcast clouds
# 5          83        7.36       broken clouds
# 6          76        7.40       broken clouds
# 7          50        7.90    scattered clouds
# 8           0        2.24           clear sky
# 9         100        5.01     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherPy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
